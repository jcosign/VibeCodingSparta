# %% [markdown]
# <a href="https://colab.research.google.com/github/jcosign/VibeCodingSparta/blob/main/report/week1/%EC%A0%95%EC%97%B0%EC%84%9C_01_print_variable_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01. print와 변수 복습
#
# 이 노트북은 Week01 Day5 easy project의 첫 번째 연습입니다. 값을 변수에 담고, 그 값을 화면에 출력하는 흐름만 확인합니다.

# %% [markdown]
# ## 1. 오늘 확인할 것
#
# - 변수에 값을 넣기
# - `print()`로 값 확인하기
# - f-string으로 문장 만들기

# %%
# TODO 1: 아래 세 값을 본인에게 맞게 아주 조금만 바꿔보세요.
student_name = "정연서"
favorite_subject = "Python 기초"
today_feeling = "복습 많이 하며 따라가야겠다"

# %% [markdown]
# ## 2. 변수 출력하기
#
# 변수를 만들었으면 바로 출력해서 내가 생각한 값이 맞는지 확인합니다.

# %%
print("이름:", student_name)
print("연습 주제:", favorite_subject)
print("상태:", today_feeling)
# Out:
# 이름: 정연서
# 연습 주제: Python 기초
# 상태: 복습 많이 하며 따라가야겠다

# %% [markdown]
# ## 3. 문장 만들기
#
# 변수 여러 개를 합쳐 한 문장으로 만들어 봅니다.

# %%
# TODO 2: 출력 문장에 들어갈 단어를 하나 바꿔보세요.
# 출력할 문장: 홍길동님은 오늘 파이썬 기초를 연습합니다.
message = f"{student_name} 학생은 {favorite_subject} 1주차 과제를 작성합니다."
print(message)
print("오늘 상태:", today_feeling)
# Out:
# 정연서 학생은 Python 기초 1주차 과제를 작성합니다.
# 오늘 상태: 복습 많이 하며 따라가야겠다

# %% [markdown]
# ## 4. 직접 출력 하나 더 만들기
#
# 부담 없이 한 줄만 더 출력해 봅니다.

# %%
# TODO 3: print 문장을 하나 더 만들어보세요.
print("조금 늦더라도 끝까지 하기")
# Out:
# 조금 늦더라도 끝까지 하기

# %% [markdown]
# ## 5. 완료 확인
#
# 아래 출력이 보이면 이 노트북은 끝까지 실행된 것입니다.

# %%
completion_log = {
    "notebook": "01_print_variable",
    "status": "PROJECT_EASY_DONE",
    "changed_cell_count": 3,
}
print(completion_log)
# Out:
# {'notebook': '01_print_variable', 'status': 'PROJECT_EASY_DONE', 'changed_cell_count': 3}
